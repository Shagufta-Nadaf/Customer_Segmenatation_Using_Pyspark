# %% [markdown]
# Customer Segmentation

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488493 sha256=d667c9f703995276fb513e122639ee93bdbd55cac3d1496872aa905c1e92841a
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("CustomerSegmentation").getOrCreate()
# This session is the entry point for interacting with Spark functionalities.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# My data is in google drive.
data="/content/drive/MyDrive/ML_Dataset/data.csv"

# %%
df = spark.read.csv(data, header=True, inferSchema=True)
df.count()
# Out:
# 541909

# %%
df.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- Country: string (nullable = true)

# %%
#check duplicate values
from pyspark.sql.functions import count, col

# Count duplicate rows based on all columns
duplicate_count = df.groupBy(df.columns).count().filter(col("count") > 1).count()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 4879

# %%
# Drop duplicate rows based on all columns
df = df.dropDuplicates()

# Show the de-duplicated DataFrame (optional)
df.show()
# Out:
# +---------+---------+--------------------+--------+----------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+----------------+---------+----------+--------------+
# |   536384|    22457|NATURAL SLATE HEA...|      12|12-01-2010 09:53|     2.95|     18074|United Kingdom|
# |   536412|    22197|SMALL POPCORN HOLDER|       5|12-01-2010 11:49|     0.85|     17920|United Kingdom|
# |   536415|    22909|SET OF 20 VINTAGE...|       5|12-01-2010 11:57|     0.85|     12838|United Kingdom|
# |   536539|    22867|HAND WARMER BIRD ...|      12|12-01-2010 14:03|      2.1|     15165|United Kingdom|
# |   536557|    79321|       CHILLI LIGHTS|      24|12-01-2010 14:41|     4.25|     17841|United Kingdom|
# |   536560|    22652|   TRAVEL SEWING KIT|      10|12-01-2010 15:00|     1.65|     13093|United Kingdom|
# |   536571|    22444|GROW YOUR OWN PLA...|      24|12-01-2010 15:37|     1.25|     14696|United Kingdom|
# |   536575|    21864|UNION JACK FLAG P...|      72|12-01-2010 16:01|     1.69|     13777|United Kingdom|
# |   536627|    22926|IVORY GIANT GARDE...|       2|12-02-2010 10:53|     5.95|     15658|United Kingdom|
# |   536638|    21041|RED RETROSPOT OVE...|       6|12-02-2010 11:41|     2.95|     16244|United Kingdom|
# |   536742|    22652|   TRAVEL SEWING KIT|       1|12-02-2010 13:14|     1.65|     16916|United Kingdom|
# |   536747|   85049E|SCANDINAVIAN REDS...|       3|12-02-2010 13:44|     1.25|     17802|United Kingdom|
# |   536759|   82494L|WOODEN FRAME ANTI...|       6|12-02-2010 14:26|     2.95|     16781|United Kingdom|
# |   536784|    16237|SLEEPING CAT ERASERS|      90|12-02-2010 15:20|     0.16|     15061|United Kingdom|
# |   536795|    21967|PACK OF 12 SKULL ...|      24|12-02-2010 15:40|     0.29|     15640|United Kingdom|
# |   536796|    22745|POPPY'S PLAYHOUSE...|       1|12-02-2010 15:46|      2.1|     15574|United Kingdom|
# |   536796|    22744|MAKE YOUR OWN MON...|       2|12-02-2010 15:46|     2.95|     15574|United Kingdom|
# |   536798|    21899|KEY FOB , GARAGE ...|      48|12-02-2010 15:55|     0.65|     17838|United Kingdom|
# |   536808|    22634|CHILDS BREAKFAST ...|       2|12-02-2010 16:46|     9.95|     17659|United Kingdom|
# |   536973|    21217|RED RETROSPOT ROU...|       4|12-03-2010 13:43|     9.95|     17787|United Kingdom|
# +---------+---------+--------------------+--------+----------------+---------+----------+--------------+
# only showing top 20 rows

# %%
#check duplicate values
from pyspark.sql.functions import count, col

# Count duplicate rows based on all columns
duplicate_count = df.groupBy(df.columns).count().filter(col("count") > 1).count()

print("Number of duplicate rows:", duplicate_count)
# Out:
# Number of duplicate rows: 0

# %%
#drop description column
df = df.drop('Description')

# %%
from pyspark.sql.functions import regexp_replace
df = df.withColumn("InvoiceDate", regexp_replace("InvoiceDate", "-", "/"))
df.show()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------+----------------+---------+----------+--------------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|
# +---------+---------+--------+----------------+---------+----------+--------------+
# only showing top 20 rows

# %%
#need to convert date which is in string to date
from pyspark.sql.functions import to_timestamp
# Creating a timestamp column to include both date and time
df = df.withColumn("Timestamp", to_timestamp(df["InvoiceDate"], "MM/dd/yyyy HH:mm"))
from pyspark.sql.functions import to_date

# Assuming your DataFrame is named df and has a column named 'Timestamp'
df = df.withColumn("Date", to_date(df["Timestamp"]))

# %%
df.printSchema()
# Out:
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: integer (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- Timestamp: timestamp (nullable = true)
#  |-- Date: date (nullable = true)

# %%
df.show()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# only showing top 20 rows

# %%
spark.conf.set("spark.sql.legacy.timeParserPolicy","LEGACY")

# %%
#checking NA values :
df.filter(df.Date.isNull()).count()

# df.toPandas(): Converts the PySpark DataFrame (df) to a Pandas DataFrame.
# Out:
# 0

# %%
#Removing Negative values from Quantity :
df = df.filter(df.Quantity > 0)
df.show()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# only showing top 20 rows

# %%
#Removing NA values
df = df.dropna()
# used to remove rows containing missing values (nulls) from a DataFrame.
# Creates new DataFrame containing rows without missing values based on specified conditions.
df.show()
df.count()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+
# only showing top 20 rows
# 392732

# %%
#Number Of countries :
df.select('Country').distinct().count()
# Out:
# 37

# %%
# sort by count
country_counts=df.groupBy('Country').count().orderBy('count', ascending=False)
country_counts.show()
# Out:
# +---------------+------+
# |        Country| count|
# +---------------+------+
# | United Kingdom|349227|
# |        Germany|  9027|
# |         France|  8327|
# |           EIRE|  7228|
# |          Spain|  2480|
# |    Netherlands|  2363|
# |        Belgium|  2031|
# |    Switzerland|  1842|
# |       Portugal|  1453|
# |      Australia|  1184|
# |         Norway|  1072|
# |          Italy|   758|
# |Channel Islands|   747|
# |        Finland|   685|
# |         Cyprus|   603|
# |         Sweden|   450|
# |        Austria|   398|
# |        Denmark|   380|
# |         Poland|   330|
# |          Japan|   321|
# +---------------+------+
# only showing top 20 rows

# %%
#plot histogram
import matplotlib.pyplot as plt
import seaborn as sns
country_counts_pd = country_counts.toPandas()
# plot histogram
plt.figure(figsize=(12,6))
sns.barplot(x='count', y='Country', data=country_counts_pd)
plt.xlabel('Count')
plt.ylabel('Country')
plt.title('Number of Customers by Country')
plt.show()

# %%
# plot line plot
plt.figure(figsize=(12,6))
plt.plot(country_counts_pd['Country'], country_counts_pd['count'])
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Number of Customers by Country')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# The goods are shipped to 37 unique countries. The majority of goods is shipped to the United Kingdom. After the United Kingdom, Germany, France and EIRE (=Ireland) are the most important countries.

# %%
# Feature Engineering :
#calculate TotalPrice
# from pyspark.sql.functions import *
from pyspark.sql.functions import round
df = df.withColumn("TotalPrice", round(df.Quantity * df.UnitPrice, 2))
df.show()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|TotalPrice|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import dayofmonth, month, year
df = df.withColumn("Day", dayofmonth(df.Date)) \
       .withColumn("Month", month(df.Date)) \
       .withColumn("Year", year(df.Date))

# %%
df.show()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|  1|   12|2010|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|  1|   12|2010|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|  1|   12|2010|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|  1|   12|2010|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|  1|   12|2010|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|  1|   12|2010|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|  1|   12|2010|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|  1|   12|2010|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|  2|   12|2010|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|  2|   12|2010|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|  2|   12|2010|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|  2|   12|2010|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|  2|   12|2010|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|  2|   12|2010|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|  2|   12|2010|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|  2|   12|2010|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|  2|   12|2010|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|  2|   12|2010|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|  2|   12|2010|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|  3|   12|2010|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+
# only showing top 20 rows

# %%
#number of transactions per month of year  2011
df.filter(df.Year == 2011).groupBy('Year', 'Month').count().orderBy('Month').show()
# Out:
# +----+-----+-----+
# |Year|Month|count|
# +----+-----+-----+
# |2011|    1|20991|
# |2011|    2|19707|
# |2011|    3|26872|
# |2011|    4|22435|
# |2011|    5|28075|
# |2011|    6|26926|
# |2011|    7|26582|
# |2011|    8|26796|
# |2011|    9|39671|
# |2011|   10|48796|
# |2011|   11|63182|
# |2011|   12|17026|
# +----+-----+-----+

# %%
#plot graph for count the number of transaction per month for 2011
#plot the number of invoices per month
day_counts = df.filter(df.Year == 2011).groupBy('Month').count().orderBy('Month').toPandas() # Convert to Pandas DataFrame
#plot histogram
#plt.figure(figsize=(12,6))
sns.barplot(x='Month', y='count', data=day_counts) # Pass the DataFrame to the 'data' parameter
plt.xlabel('Month') # Correct x-axis label
plt.ylabel('Count') # Correct y-axis label
plt.title('Number of Invoices per Month in 2011') # Correct title
plt.show()

# %%
# Check the distinct days in Nov 2011
df.filter((df.Year == 2011) & (df.Month==11)).select('Day').distinct().orderBy('Day').show()
# Out:
# +---+
# |Day|
# +---+
# |  1|
# |  2|
# |  3|
# |  4|
# |  6|
# |  7|
# |  8|
# |  9|
# | 10|
# | 11|
# | 13|
# | 14|
# | 15|
# | 16|
# | 17|
# | 18|
# | 20|
# | 21|
# | 22|
# | 23|
# +---+
# only showing top 20 rows

# %%
#plot the number of invoices per day
day_counts = df.filter((df.Year == 2011) & (df.Month==11)).groupBy('Day').count().orderBy('Day').toPandas() # Convert to Pandas DataFrame
#plot histogram
# plt.figure(figsize=(12,6))
sns.barplot(x='Day', y='count', data=day_counts) # Pass the DataFrame to the 'data' parameter
plt.xlabel('Day') # Correct x-axis label
plt.ylabel('Count') # Correct y-axis label
plt.title('Number of Invoices per Day in 2011') # Correct title
plt.show()

# %%
#seprate date into day format as monday tuesday and so on
from pyspark.sql.functions import date_format
df = df.withColumn("DayName", date_format(df.Date, "EEEE"))
df.show()
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+---------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|  DayName|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+---------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|  1|   12|2010|Wednesday|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|  1|   12|2010|Wednesday|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|  1|   12|2010|Wednesday|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|  1|   12|2010|Wednesday|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|  1|   12|2010|Wednesday|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|  1|   12|2010|Wednesday|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|  2|   12|2010| Thursday|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|  2|   12|2010| Thursday|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|  2|   12|2010| Thursday|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|  2|   12|2010| Thursday|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|  2|   12|2010| Thursday|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|  2|   12|2010| Thursday|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|  2|   12|2010| Thursday|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|  2|   12|2010| Thursday|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|  2|   12|2010| Thursday|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|  2|   12|2010| Thursday|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|  2|   12|2010| Thursday|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|  3|   12|2010|   Friday|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+---------+
# only showing top 20 rows

# %%
#plot the number of invoices per DayName
day_counts = df.filter((df.Year == 2011) & (df.Month==11)).groupBy('DayName').count().orderBy('DayName').toPandas() # Convert to Pandas DataFrame
#plot histogram
plt.figure(figsize=(10,6))
sns.barplot(x='DayName', y='count', data=day_counts)
plt.xlabel('DayName')
plt.ylabel('Count')
plt.title('Number of Invoices per DayName')
plt.show()

# %%
day_counts = df.filter((df.Year == 2011) & (df.Month==11)).groupBy('DayName').count().orderBy('DayName').toPandas()
plt.figure(figsize=(12,6))
plt.pie(day_counts['count'], labels=day_counts['DayName'], autopct='%1.2f%%', startangle=90)
plt.title('Number of Invoices per DayName in November 2011')
plt.show()

# %%
# RFM :

# RECENCY - how recent did a customer bought something
# FREQUENCY - how often does a customer buy something
# MONETARY VALUE - what is the value of the purchased items

# %%
#last date or latest date available in our dataset with format
from pyspark.sql.functions import max, date_format

# Get the latest date and format it
latest_date_formatted = df.agg(date_format(max("Date"), "MM-dd-yyyy").alias("LatestDate")).collect()[0][0]

print(latest_date_formatted)
# Out:
# 12-09-2011

# %%
from pyspark.sql.functions import datediff, lit, to_date

# Ensure both dates are in a consistent format
df = df.withColumn("Date", to_date(df.Date, "MM-dd-yyyy"))
df = df.withColumn("Recency", datediff(to_date(lit("12-09-2011"), "MM-dd-yyyy"), df.Date))
df.show()

#12-09-2011-2010-12-01=365+(9-1)=365+8=  373
# Out:
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+
# |InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|CustomerID|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|  DayName|Recency|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+
# |   536384|    22457|      12|12/01/2010 09:53|     2.95|     18074|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|  1|   12|2010|Wednesday|    373|
# |   536412|    22197|       5|12/01/2010 11:49|     0.85|     17920|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|
# |   536415|    22909|       5|12/01/2010 11:57|     0.85|     12838|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|
# |   536539|    22867|      12|12/01/2010 14:03|      2.1|     15165|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|  1|   12|2010|Wednesday|    373|
# |   536557|    79321|      24|12/01/2010 14:41|     4.25|     17841|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|  1|   12|2010|Wednesday|    373|
# |   536560|    22652|      10|12/01/2010 15:00|     1.65|     13093|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|  1|   12|2010|Wednesday|    373|
# |   536571|    22444|      24|12/01/2010 15:37|     1.25|     14696|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|  1|   12|2010|Wednesday|    373|
# |   536575|    21864|      72|12/01/2010 16:01|     1.69|     13777|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|  1|   12|2010|Wednesday|    373|
# |   536627|    22926|       2|12/02/2010 10:53|     5.95|     15658|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|  2|   12|2010| Thursday|    372|
# |   536638|    21041|       6|12/02/2010 11:41|     2.95|     16244|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|
# |   536742|    22652|       1|12/02/2010 13:14|     1.65|     16916|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|  2|   12|2010| Thursday|    372|
# |   536747|   85049E|       3|12/02/2010 13:44|     1.25|     17802|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|  2|   12|2010| Thursday|    372|
# |   536759|   82494L|       6|12/02/2010 14:26|     2.95|     16781|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|
# |   536784|    16237|      90|12/02/2010 15:20|     0.16|     15061|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|  2|   12|2010| Thursday|    372|
# |   536795|    21967|      24|12/02/2010 15:40|     0.29|     15640|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|  2|   12|2010| Thursday|    372|
# |   536796|    22745|       1|12/02/2010 15:46|      2.1|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|  2|   12|2010| Thursday|    372|
# |   536796|    22744|       2|12/02/2010 15:46|     2.95|     15574|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|  2|   12|2010| Thursday|    372|
# |   536798|    21899|      48|12/02/2010 15:55|     0.65|     17838|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|  2|   12|2010| Thursday|    372|
# |   536808|    22634|       2|12/02/2010 16:46|     9.95|     17659|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|  2|   12|2010| Thursday|    372|
# |   536973|    21217|       4|12/03/2010 13:43|     9.95|     17787|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|  3|   12|2010|   Friday|    371|
# +---------+---------+--------+----------------+---------+----------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+
# only showing top 20 rows

# %% [markdown]
# Recency
# Recency was calculated as one of the features for the segmentation analysis. In this case recency has been calculated as follows, time of customer’s last purchase minus Latest date

# %%
#calculate frequency of purchase(number of purchases made by each customer.)
df.groupBy('CustomerID').agg(count('*').alias('Frequency')).orderBy('Frequency', ascending=False).show()

#show frequency in df as column
df_frequency = df.groupBy('CustomerID').agg(count('*').alias('Frequency')) # Calculate frequency and store in a separate DataFrame
df = df.join(df_frequency, 'CustomerID') # Join the original DataFrame with the frequency DataFrame
df.show()
# Out:
# +----------+---------+
# |CustomerID|Frequency|
# +----------+---------+
# |     17841|     7676|
# |     14911|     5672|
# |     14096|     5111|
# |     12748|     4413|
# |     14606|     2677|
# |     15311|     2366|
# |     14646|     2080|
# |     13089|     1814|
# |     13263|     1667|
# |     14298|     1637|
# |     15039|     1477|
# |     14156|     1395|
# |     18118|     1263|
# |     14159|     1175|
# |     14796|     1132|
# |     16033|     1128|
# |     15005|     1112|
# |     14056|     1088|
# |     14769|     1062|
# |     13081|     1028|
# +----------+---------+
# only showing top 20 rows
#
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+
# |CustomerID|InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|  DayName|Recency|Frequency|
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+
# |     18074|   536384|    22457|      12|12/01/2010 09:53|     2.95|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|  1|   12|2010|Wednesday|    373|       13|
# |     17920|   536412|    22197|       5|12/01/2010 11:49|     0.85|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|      665|
# |     12838|   536415|    22909|       5|12/01/2010 11:57|     0.85|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|      120|
# |     15165|   536539|    22867|      12|12/01/2010 14:03|      2.1|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|  1|   12|2010|Wednesday|    373|       27|
# |     17841|   536557|    79321|      24|12/01/2010 14:41|     4.25|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|  1|   12|2010|Wednesday|    373|     7676|
# |     13093|   536560|    22652|      10|12/01/2010 15:00|     1.65|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|  1|   12|2010|Wednesday|    373|      159|
# |     14696|   536571|    22444|      24|12/01/2010 15:37|     1.25|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|  1|   12|2010|Wednesday|    373|      130|
# |     13777|   536575|    21864|      72|12/01/2010 16:01|     1.69|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|  1|   12|2010|Wednesday|    373|      197|
# |     15658|   536627|    22926|       2|12/02/2010 10:53|     5.95|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|  2|   12|2010| Thursday|    372|       48|
# |     16244|   536638|    21041|       6|12/02/2010 11:41|     2.95|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|       91|
# |     16916|   536742|    22652|       1|12/02/2010 13:14|     1.65|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|  2|   12|2010| Thursday|    372|      136|
# |     17802|   536747|   85049E|       3|12/02/2010 13:44|     1.25|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|  2|   12|2010| Thursday|    372|      140|
# |     16781|   536759|   82494L|       6|12/02/2010 14:26|     2.95|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|       17|
# |     15061|   536784|    16237|      90|12/02/2010 15:20|     0.16|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|  2|   12|2010| Thursday|    372|      403|
# |     15640|   536795|    21967|      24|12/02/2010 15:40|     0.29|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|  2|   12|2010| Thursday|    372|      476|
# |     15574|   536796|    22745|       1|12/02/2010 15:46|      2.1|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|  2|   12|2010| Thursday|    372|      152|
# |     15574|   536796|    22744|       2|12/02/2010 15:46|     2.95|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|  2|   12|2010| Thursday|    372|      152|
# |     17838|   536798|    21899|      48|12/02/2010 15:55|     0.65|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|  2|   12|2010| Thursday|    372|      117|
# |     17659|   536808|    22634|       2|12/02/2010 16:46|     9.95|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|  2|   12|2010| Thursday|    372|      158|
# |     17787|   536973|    21217|       4|12/03/2010 13:43|     9.95|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|  3|   12|2010|   Friday|    371|      128|
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import sum, col
df = df.withColumn("TotalPrice", col("TotalPrice").cast("float"))
# Monetary Value of Customers
df.groupBy('CustomerID').agg(round(sum('TotalPrice'),2).alias('MonetaryValue')).orderBy('MonetaryValue',ascending=False).show()
#show Monetary in df as column
df_monetary = df.groupBy('CustomerID').agg(round(sum('TotalPrice'),2).alias('MonetaryValues')) # Calculate Monetary and store in a separate DataFrame
df = df.join(df_monetary, 'CustomerID') # Join the original DataFrame with the Monetary DataFrame
df.show()
# Out:
# +----------+-------------+
# |CustomerID|MonetaryValue|
# +----------+-------------+
# |     14646|    280206.02|
# |     18102|     259657.3|
# |     17450|    194390.79|
# |     16446|    168472.49|
# |     14911|    143711.17|
# |     12415|    124914.53|
# |     14156|    117210.08|
# |     17511|     91062.38|
# |     16029|     80850.84|
# |     12346|      77183.6|
# |     16684|     66653.56|
# |     14096|     65164.79|
# |     13694|     65039.62|
# |     15311|     60632.75|
# |     13089|     58762.08|
# |     17949|     58510.48|
# |     15769|     56252.72|
# |     15061|     54534.14|
# |     14298|      51527.3|
# |     14088|     50491.81|
# +----------+-------------+
# only showing top 20 rows
#
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+--------------+
# |CustomerID|InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|  DayName|Recency|Frequency|MonetaryValues|
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+--------------+
# |     18074|   536384|    22457|      12|12/01/2010 09:53|     2.95|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|  1|   12|2010|Wednesday|    373|       13|         489.6|
# |     17920|   536412|    22197|       5|12/01/2010 11:49|     0.85|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|      665|        4119.5|
# |     12838|   536415|    22909|       5|12/01/2010 11:57|     0.85|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|      120|        671.95|
# |     15165|   536539|    22867|      12|12/01/2010 14:03|      2.1|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|  1|   12|2010|Wednesday|    373|       27|        487.75|
# |     17841|   536557|    79321|      24|12/01/2010 14:41|     4.25|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|  1|   12|2010|Wednesday|    373|     7676|      40519.84|
# |     13093|   536560|    22652|      10|12/01/2010 15:00|     1.65|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|  1|   12|2010|Wednesday|    373|      159|       7832.47|
# |     14696|   536571|    22444|      24|12/01/2010 15:37|     1.25|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|  1|   12|2010|Wednesday|    373|      130|       2078.95|
# |     13777|   536575|    21864|      72|12/01/2010 16:01|     1.69|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|  1|   12|2010|Wednesday|    373|      197|      25977.16|
# |     15658|   536627|    22926|       2|12/02/2010 10:53|     5.95|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|  2|   12|2010| Thursday|    372|       48|        1024.1|
# |     16244|   536638|    21041|       6|12/02/2010 11:41|     2.95|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|       91|       1522.75|
# |     16916|   536742|    22652|       1|12/02/2010 13:14|     1.65|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|  2|   12|2010| Thursday|    372|      136|        562.41|
# |     17802|   536747|   85049E|       3|12/02/2010 13:44|     1.25|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|  2|   12|2010| Thursday|    372|      140|       1285.04|
# |     16781|   536759|   82494L|       6|12/02/2010 14:26|     2.95|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|       17|        311.25|
# |     15061|   536784|    16237|      90|12/02/2010 15:20|     0.16|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|  2|   12|2010| Thursday|    372|      403|      54534.14|
# |     15640|   536795|    21967|      24|12/02/2010 15:40|     0.29|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|  2|   12|2010| Thursday|    372|      476|      12416.11|
# |     15574|   536796|    22745|       1|12/02/2010 15:46|      2.1|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|  2|   12|2010| Thursday|    372|      152|        675.64|
# |     15574|   536796|    22744|       2|12/02/2010 15:46|     2.95|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|  2|   12|2010| Thursday|    372|      152|        675.64|
# |     17838|   536798|    21899|      48|12/02/2010 15:55|     0.65|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|  2|   12|2010| Thursday|    372|      117|        2720.8|
# |     17659|   536808|    22634|       2|12/02/2010 16:46|     9.95|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|  2|   12|2010| Thursday|    372|      158|       2999.46|
# |     17787|   536973|    21217|       4|12/03/2010 13:43|     9.95|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|  3|   12|2010|   Friday|    371|      128|       1817.54|
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+--------------+
# only showing top 20 rows

# %%
# Total spent on each item on an invoice
df.groupBy('InvoiceNo').agg(round(sum('TotalPrice'),1).alias('TotalSpent')).show()
# Out:
# +---------+----------+
# |InvoiceNo|TotalSpent|
# +---------+----------+
# |   541783|     728.2|
# |   547122|     298.1|
# |   550469|     178.4|
# |   553708|     112.2|
# |   556732|     474.9|
# |   536938|    1680.9|
# |   540976|     920.0|
# |   541518|    2919.5|
# |   542375|     178.1|
# |   558700|     295.4|
# |   561519|      84.0|
# |   562204|     249.3|
# |   544303|     161.9|
# |   545583|     317.3|
# |   553390|     466.3|
# |   557271|     621.3|
# |   559295|     303.8|
# |   560145|     709.7|
# |   538879|     339.0|
# |   552277|     312.3|
# +---------+----------+
# only showing top 20 rows

# %%
# Visualizing a histogram of revenue generated by user
# !pip install pyspark matplotlib
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
dayname_counts = df.groupBy('Country', 'DayName').count()
dayname_counts_pd = dayname_counts.toPandas()
import matplotlib.pyplot as plt
import seaborn as sns

#  'United Kingdom'
country_data = dayname_counts_pd[dayname_counts_pd['Country'] == 'United Kingdom']
# Plot the line chart using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x='DayName', y='count', data=country_data)
plt.xlabel('DayName')
plt.ylabel('Count')
plt.title('Distribution of DayName for United Kingdom')
plt.show()

# %%
# # #drop MonetaryValue column
# df = df.drop('MonetaryValue')
# df=df.drop('MonetaryValues')
# # df.show()

# %%
df.show()
# Out:
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+--------------+
# |CustomerID|InvoiceNo|StockCode|Quantity|     InvoiceDate|UnitPrice|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|  DayName|Recency|Frequency|MonetaryValues|
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+--------------+
# |     18074|   536384|    22457|      12|12/01/2010 09:53|     2.95|United Kingdom|2010-12-01 09:53:00|2010-12-01|      35.4|  1|   12|2010|Wednesday|    373|       13|         489.6|
# |     17920|   536412|    22197|       5|12/01/2010 11:49|     0.85|United Kingdom|2010-12-01 11:49:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|      665|        4119.5|
# |     12838|   536415|    22909|       5|12/01/2010 11:57|     0.85|United Kingdom|2010-12-01 11:57:00|2010-12-01|      4.25|  1|   12|2010|Wednesday|    373|      120|        671.95|
# |     15165|   536539|    22867|      12|12/01/2010 14:03|      2.1|United Kingdom|2010-12-01 14:03:00|2010-12-01|      25.2|  1|   12|2010|Wednesday|    373|       27|        487.75|
# |     17841|   536557|    79321|      24|12/01/2010 14:41|     4.25|United Kingdom|2010-12-01 14:41:00|2010-12-01|     102.0|  1|   12|2010|Wednesday|    373|     7676|      40519.84|
# |     13093|   536560|    22652|      10|12/01/2010 15:00|     1.65|United Kingdom|2010-12-01 15:00:00|2010-12-01|      16.5|  1|   12|2010|Wednesday|    373|      159|       7832.47|
# |     14696|   536571|    22444|      24|12/01/2010 15:37|     1.25|United Kingdom|2010-12-01 15:37:00|2010-12-01|      30.0|  1|   12|2010|Wednesday|    373|      130|       2078.95|
# |     13777|   536575|    21864|      72|12/01/2010 16:01|     1.69|United Kingdom|2010-12-01 16:01:00|2010-12-01|    121.68|  1|   12|2010|Wednesday|    373|      197|      25977.16|
# |     15658|   536627|    22926|       2|12/02/2010 10:53|     5.95|United Kingdom|2010-12-02 10:53:00|2010-12-02|      11.9|  2|   12|2010| Thursday|    372|       48|        1024.1|
# |     16244|   536638|    21041|       6|12/02/2010 11:41|     2.95|United Kingdom|2010-12-02 11:41:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|       91|       1522.75|
# |     16916|   536742|    22652|       1|12/02/2010 13:14|     1.65|United Kingdom|2010-12-02 13:14:00|2010-12-02|      1.65|  2|   12|2010| Thursday|    372|      136|        562.41|
# |     17802|   536747|   85049E|       3|12/02/2010 13:44|     1.25|United Kingdom|2010-12-02 13:44:00|2010-12-02|      3.75|  2|   12|2010| Thursday|    372|      140|       1285.04|
# |     16781|   536759|   82494L|       6|12/02/2010 14:26|     2.95|United Kingdom|2010-12-02 14:26:00|2010-12-02|      17.7|  2|   12|2010| Thursday|    372|       17|        311.25|
# |     15061|   536784|    16237|      90|12/02/2010 15:20|     0.16|United Kingdom|2010-12-02 15:20:00|2010-12-02|      14.4|  2|   12|2010| Thursday|    372|      403|      54534.14|
# |     15640|   536795|    21967|      24|12/02/2010 15:40|     0.29|United Kingdom|2010-12-02 15:40:00|2010-12-02|      6.96|  2|   12|2010| Thursday|    372|      476|      12416.11|
# |     15574|   536796|    22745|       1|12/02/2010 15:46|      2.1|United Kingdom|2010-12-02 15:46:00|2010-12-02|       2.1|  2|   12|2010| Thursday|    372|      152|        675.64|
# |     15574|   536796|    22744|       2|12/02/2010 15:46|     2.95|United Kingdom|2010-12-02 15:46:00|2010-12-02|       5.9|  2|   12|2010| Thursday|    372|      152|        675.64|
# |     17838|   536798|    21899|      48|12/02/2010 15:55|     0.65|United Kingdom|2010-12-02 15:55:00|2010-12-02|      31.2|  2|   12|2010| Thursday|    372|      117|        2720.8|
# |     17659|   536808|    22634|       2|12/02/2010 16:46|     9.95|United Kingdom|2010-12-02 16:46:00|2010-12-02|      19.9|  2|   12|2010| Thursday|    372|      158|       2999.46|
# |     17787|   536973|    21217|       4|12/03/2010 13:43|     9.95|United Kingdom|2010-12-03 13:43:00|2010-12-03|      39.8|  3|   12|2010|   Friday|    371|      128|       1817.54|
# +----------+---------+---------+--------+----------------+---------+--------------+-------------------+----------+----------+---+-----+----+---------+-------+---------+--------------+
# only showing top 20 rows

# %%
#create RFM table with column MonetaryValue,Frequency and Recency
df_rfm = df.select('CustomerID', 'Recency', 'Frequency','MonetaryValues','Date')
df_rfm.show()
# Out:
# +----------+-------+---------+--------------+----------+
# |CustomerID|Recency|Frequency|MonetaryValues|      Date|
# +----------+-------+---------+--------------+----------+
# |     18074|    373|       13|         489.6|2010-12-01|
# |     17920|    373|      665|        4119.5|2010-12-01|
# |     12838|    373|      120|        671.95|2010-12-01|
# |     15165|    373|       27|        487.75|2010-12-01|
# |     17841|    373|     7676|      40519.84|2010-12-01|
# |     13093|    373|      159|       7832.47|2010-12-01|
# |     14696|    373|      130|       2078.95|2010-12-01|
# |     13777|    373|      197|      25977.16|2010-12-01|
# |     15658|    372|       48|        1024.1|2010-12-02|
# |     16244|    372|       91|       1522.75|2010-12-02|
# |     16916|    372|      136|        562.41|2010-12-02|
# |     17802|    372|      140|       1285.04|2010-12-02|
# |     16781|    372|       17|        311.25|2010-12-02|
# |     15061|    372|      403|      54534.14|2010-12-02|
# |     15640|    372|      476|      12416.11|2010-12-02|
# |     15574|    372|      152|        675.64|2010-12-02|
# |     15574|    372|      152|        675.64|2010-12-02|
# |     17838|    372|      117|        2720.8|2010-12-02|
# |     17659|    372|      158|       2999.46|2010-12-02|
# |     17787|    371|      128|       1817.54|2010-12-03|
# +----------+-------+---------+--------------+----------+
# only showing top 20 rows

# %%
#give customer id where recency is null show only customerid
df_rfm.filter(df_rfm.Recency.isNull()).select('CustomerID').show()
#give count how many null values are there in recency
df_rfm.filter(df_rfm.Recency.isNull()).count()
# Out:
# +----------+
# |CustomerID|
# +----------+
# +----------+
# 0

# %%
#for particular customerid =12362 give all data
df.filter(df_rfm.CustomerID == 12346).show()
# Out:
# +----------+---------+---------+--------+---------------+---------+--------------+-------------------+----------+----------+---+-----+----+-------+-------+---------+--------------+
# |CustomerID|InvoiceNo|StockCode|Quantity|    InvoiceDate|UnitPrice|       Country|          Timestamp|      Date|TotalPrice|Day|Month|Year|DayName|Recency|Frequency|MonetaryValues|
# +----------+---------+---------+--------+---------------+---------+--------------+-------------------+----------+----------+---+-----+----+-------+-------+---------+--------------+
# |     12346|   541431|    23166|   74215|1/18/2011 10:01|     1.04|United Kingdom|2011-01-18 10:01:00|2011-01-18|   77183.6| 18|    1|2011|Tuesday|    325|        1|       77183.6|
# +----------+---------+---------+--------+---------------+---------+--------------+-------------------+----------+----------+---+-----+----+-------+-------+---------+--------------+

# %%
#RFM Quartiles
# Calculate quartiles on df_rfm table for recency,frequency and monetaryvalues
rfm_quantiles = df_rfm.selectExpr("percentile_approx(Recency, array(0.25, 0.5,0.75)) as recency_quantiles",
                                   "percentile_approx(Frequency, array(0.25, 0.5,0.75)) as frequency_quantiles",
                                   "percentile_approx(MonetaryValues, array(0.25, 0.5,0.75)) as monetary_quantiles")
rfm_quantiles.show()
# Out:
# +-----------------+-------------------+--------------------+
# |recency_quantiles|frequency_quantiles|  monetary_quantiles|
# +-----------------+-------------------+--------------------+
# |   [50, 131, 246]|     [89, 197, 441]|[1097.62, 2662.06...|
# +-----------------+-------------------+--------------------+

# %%
#convert quartile to dict
rfm_quantiles_dict = rfm_quantiles.first().asDict()
rfm_quantiles_dict
# Out:
# {'recency_quantiles': [50, 131, 246],
#  'frequency_quantiles': [89, 197, 441],
#  'monetary_quantiles': [1097.62, 2662.06, 6287.77]}

# %%
#Creation of RFM Segment
# Arguments (x = value, p = recency, monetary_value, frequency, d = quartiles dict)
from pyspark.sql.functions import udf
from pyspark.sql.types import IntegerType

# Assuming 'quantiles' is a broadcast variable containing the quartiles dictionary
quantiles_broadcast = spark.sparkContext.broadcast(rfm_quantiles_dict)

def RScore(x, p):
    quantiles = quantiles_broadcast.value
    if x <= quantiles[p.lower()+'_quantiles'][0]:
        return 4
    elif x <= quantiles[p.lower()+'_quantiles'][1]:
        return 3
    elif x <= quantiles[p.lower()+'_quantiles'][2]:
        return 2
    else:
        return 1

RScore_udf = udf(RScore, IntegerType())

# Example usage:
# Assuming 'rfm_df' is a PySpark DataFrame with a 'recency_quantiles' column
from pyspark.sql.functions import lit

#quantiles_broadcast = spark.sparkContext.broadcast(your_quartiles_dict)




def FMScore(x, p):
    quantiles = quantiles_broadcast.value
    if x <= quantiles[p.lower()+'_quantiles'][0]:
        return 1
    elif x <= quantiles[p.lower()+'_quantiles'][1]:
        return 2
    elif x <= quantiles[p.lower()+'_quantiles'][2]:
        return 3
    else:
        return 4


FMScore_udf = udf(FMScore, IntegerType())

# %%
df_with_scores = df_rfm.withColumn('F_Quartile', FMScore_udf(df_rfm['Frequency'], lit('Frequency')))
df_with_scores = df_with_scores.withColumn('M_Quartile', FMScore_udf(df_with_scores['MonetaryValues'], lit('Monetary')))

df_with_scores = df_with_scores.withColumn('R_Quartile', RScore_udf(df_with_scores['Recency'], lit('Recency')))
df_with_scores.show()
# Out:
# +----------+-------+---------+--------------+----------+----------+----------+----------+
# |CustomerID|Recency|Frequency|MonetaryValues|      Date|F_Quartile|M_Quartile|R_Quartile|
# +----------+-------+---------+--------------+----------+----------+----------+----------+
# |     18074|    373|       13|         489.6|2010-12-01|         1|         1|         1|
# |     17920|    373|      665|        4119.5|2010-12-01|         4|         3|         1|
# |     12838|    373|      120|        671.95|2010-12-01|         2|         1|         1|
# |     15165|    373|       27|        487.75|2010-12-01|         1|         1|         1|
# |     17841|    373|     7676|      40519.84|2010-12-01|         4|         4|         1|
# |     13093|    373|      159|       7832.47|2010-12-01|         2|         4|         1|
# |     14696|    373|      130|       2078.95|2010-12-01|         2|         2|         1|
# |     13777|    373|      197|      25977.16|2010-12-01|         2|         4|         1|
# |     15658|    372|       48|        1024.1|2010-12-02|         1|         1|         1|
# |     16244|    372|       91|       1522.75|2010-12-02|         2|         2|         1|
# |     16916|    372|      136|        562.41|2010-12-02|         2|         1|         1|
# |     17802|    372|      140|       1285.04|2010-12-02|         2|         2|         1|
# |     16781|    372|       17|        311.25|2010-12-02|         1|         1|         1|
# |     15061|    372|      403|      54534.14|2010-12-02|         3|         4|         1|
# |     15640|    372|      476|      12416.11|2010-12-02|         4|         4|         1|
# |     15574|    372|      152|        675.64|2010-12-02|         2|         1|         1|
# |     15574|    372|      152|        675.64|2010-12-02|         2|         1|         1|
# |     17838|    372|      117|        2720.8|2010-12-02|         2|         3|         1|
# |     17659|    372|      158|       2999.46|2010-12-02|         2|         3|         1|
# |     17787|    371|      128|       1817.54|2010-12-03|         2|         2|         1|
# +----------+-------+---------+--------------+----------+----------+----------+----------+
# only showing top 20 rows

# %%
#create RFM score table
from pyspark.sql.functions import concat, col
df_with_scores = df_with_scores.withColumn('RFM_Score', concat(col('R_Quartile'), col('F_Quartile'), col('M_Quartile')))
df_with_scores.show()
# Out:
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# |CustomerID|Recency|Frequency|MonetaryValues|      Date|F_Quartile|M_Quartile|R_Quartile|RFM_Score|
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# |     18074|    373|       13|         489.6|2010-12-01|         1|         1|         1|      111|
# |     17920|    373|      665|        4119.5|2010-12-01|         4|         3|         1|      143|
# |     12838|    373|      120|        671.95|2010-12-01|         2|         1|         1|      121|
# |     15165|    373|       27|        487.75|2010-12-01|         1|         1|         1|      111|
# |     17841|    373|     7676|      40519.84|2010-12-01|         4|         4|         1|      144|
# |     13093|    373|      159|       7832.47|2010-12-01|         2|         4|         1|      124|
# |     14696|    373|      130|       2078.95|2010-12-01|         2|         2|         1|      122|
# |     13777|    373|      197|      25977.16|2010-12-01|         2|         4|         1|      124|
# |     15658|    372|       48|        1024.1|2010-12-02|         1|         1|         1|      111|
# |     16244|    372|       91|       1522.75|2010-12-02|         2|         2|         1|      122|
# |     16916|    372|      136|        562.41|2010-12-02|         2|         1|         1|      121|
# |     17802|    372|      140|       1285.04|2010-12-02|         2|         2|         1|      122|
# |     16781|    372|       17|        311.25|2010-12-02|         1|         1|         1|      111|
# |     15061|    372|      403|      54534.14|2010-12-02|         3|         4|         1|      134|
# |     15640|    372|      476|      12416.11|2010-12-02|         4|         4|         1|      144|
# |     15574|    372|      152|        675.64|2010-12-02|         2|         1|         1|      121|
# |     15574|    372|      152|        675.64|2010-12-02|         2|         1|         1|      121|
# |     17838|    372|      117|        2720.8|2010-12-02|         2|         3|         1|      123|
# |     17659|    372|      158|       2999.46|2010-12-02|         2|         3|         1|      123|
# |     17787|    371|      128|       1817.54|2010-12-03|         2|         2|         1|      122|
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# only showing top 20 rows

# %%
#best customer
df_with_scores.filter(df_with_scores.RFM_Score == '444').show()
# Out:
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# |CustomerID|Recency|Frequency|MonetaryValues|      Date|F_Quartile|M_Quartile|R_Quartile|RFM_Score|
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# |     14911|     50|     5672|     143711.17|2011-10-20|         4|         4|         4|      444|
# |     14911|     50|     5672|     143711.17|2011-10-20|         4|         4|         4|      444|
# |     14527|     50|      971|       8507.13|2011-10-20|         4|         4|         4|      444|
# |     14646|     50|     2080|     280206.02|2011-10-20|         4|         4|         4|      444|
# |     14606|     50|     2677|      12076.15|2011-10-20|         4|         4|         4|      444|
# |     14911|     50|     5672|     143711.17|2011-10-20|         4|         4|         4|      444|
# |     12921|     46|      720|      16587.09|2011-10-24|         4|         4|         4|      444|
# |     14895|     46|      498|      11138.71|2011-10-24|         4|         4|         4|      444|
# |     14096|     46|     5111|      65164.79|2011-10-24|         4|         4|         4|      444|
# |     14606|     44|     2677|      12076.15|2011-10-26|         4|         4|         4|      444|
# |     15311|     44|     2366|      60632.75|2011-10-26|         4|         4|         4|      444|
# |     15044|     39|      444|       7634.73|2011-10-31|         4|         4|         4|      444|
# |     14096|     39|     5111|      65164.79|2011-10-31|         4|         4|         4|      444|
# |     14096|     39|     5111|      65164.79|2011-10-31|         4|         4|         4|      444|
# |     14667|     38|      567|       9175.04|2011-11-01|         4|         4|         4|      444|
# |     13081|     35|     1028|      28337.38|2011-11-04|         4|         4|         4|      444|
# |     17841|     35|     7676|      40519.84|2011-11-04|         4|         4|         4|      444|
# |     17841|     31|     7676|      40519.84|2011-11-08|         4|         4|         4|      444|
# |     12921|     30|      720|      16587.09|2011-11-09|         4|         4|         4|      444|
# |     14298|     30|     1637|       51527.3|2011-11-09|         4|         4|         4|      444|
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# only showing top 20 rows

# %%
#top 5 customer having rfm score=444
top_five=df_with_scores.filter(df_with_scores.RFM_Score == '444').orderBy('MonetaryValues', ascending=False).show(5)
# Out:
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# |CustomerID|Recency|Frequency|MonetaryValues|      Date|F_Quartile|M_Quartile|R_Quartile|RFM_Score|
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# |     14646|     16|     2080|     280206.02|2011-11-23|         4|         4|         4|      444|
# |     14646|     50|     2080|     280206.02|2011-10-20|         4|         4|         4|      444|
# |     14646|     43|     2080|     280206.02|2011-10-27|         4|         4|         4|      444|
# |     14646|     29|     2080|     280206.02|2011-11-10|         4|         4|         4|      444|
# |     14646|      2|     2080|     280206.02|2011-12-07|         4|         4|         4|      444|
# +----------+-------+---------+--------------+----------+----------+----------+----------+---------+
# only showing top 5 rows

# %%
# top 5 customers having rfm score = 444 plot
df_pandas = df_with_scores.toPandas()
top_5_customers = df_pandas[df_pandas['RFM_Score'] == '444'].nlargest(5, 'MonetaryValues')
plt.figure(figsize=(10, 6))
sns.scatterplot(data=top_5_customers, x='CustomerID', y='RFM_Score', hue='RFM_Score', size='MonetaryValues',
                palette='viridis', sizes=(50, 200))

# Highlight customers with 444 RFM score
plt.scatter(top_5_customers['CustomerID'], top_5_customers['RFM_Score'], color='green', marker='*', s=200, label='444 RFM Score')

plt.title('RFM Segmentation Scatter Plot')
plt.xlabel('CustomerID')
plt.ylabel('RFM_Score')
plt.legend()
plt.show()

# %%
# Assuming 'rfm_segmentation' is a PySpark DataFrame

# Best Customers
best_customers_count = df_with_scores.filter(df_with_scores['RFM_Score'] == '444').count()
print("Best Customers: ", best_customers_count)

# Loyal Customers
loyal_customers_count = df_with_scores.filter(df_with_scores['F_Quartile'] == 4).count()
print('Loyal Customers: ', loyal_customers_count)

# Big Spenders
big_spenders_count =df_with_scores.filter(df_with_scores['M_Quartile'] == 4).count()
print("Big Spenders: ", big_spenders_count)

# Almost Lost
almost_lost_count = df_with_scores.filter(df_with_scores['RFM_Score'] == '244').count()
print('Almost Lost: ', almost_lost_count)

# Lost Customers
lost_customers_count = df_with_scores.filter(df_with_scores['RFM_Score'] == '144').count()
print('Lost Customers: ', lost_customers_count)
# Out:
# Best Customers:  16883
# Loyal Customers:  97801
# Big Spenders:  98173
# Almost Lost:  17781
# Lost Customers:  16234
